# %% [markdown]
# # **Package Installation**

# %%
# !pip install quandl

# %%
pip install yahoofinancials
# Out:
# ...
#   Created wheel for yahoofinancials: filename=yahoofinancials-1.6-cp36-none-any.whl size=15192 sha256=dbc0f58f87d67f7b415e62a818b32d6d2549ae10107cc3912fb9bbfc6276a369
#   Stored in directory: /root/.cache/pip/wheels/d9/7e/cf/4977a8572d5247242a4b13018d1d36923024ba84236e0d28bc
# Successfully built yahoofinancials
# ...

# %%
pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 5.5MB 17.0MB/s
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22616 sha256=9d341e930c73088994d9e393c2a804340b5b227fcddcae86c62b4c050e364e1c
#   Stored in directory: /root/.cache/pip/wheels/04/98/cc/2702a4242d60bdc14f48b4557c427ded1fe92aedf257d4565c
# Successfully built yfinance
# ...
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %% [markdown]
# #**Import Package**

# %%
import numpy as np
import pandas as pd
import datetime
from matplotlib import pyplot as plt
import pandas_datareader.data as web
from google.colab import files
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials
import seaborn as sns
from sklearn.metrics import confusion_matrix
import pandas as pd

# %% [markdown]
# # **DATA COLLECTION FROM YAHOO**

# %% [markdown]
# Amazon 5 years data (2015-2020)

# %%
AMAZ_15to20= web.DataReader("AMZN", "yahoo", datetime.datetime(2015,1,1), datetime.date.today())
AMAZ_15to20.head()
# Out:
#                   High         Low        Open       Close   Volume   Adj Close
# Date
# 2015-01-02  314.750000  306.959991  312.579987  308.519989  2783200  308.519989
# 2015-01-05  308.380005  300.850006  307.010010  302.190002  2774200  302.190002
# 2015-01-06  303.000000  292.380005  302.239990  295.290009  3519000  295.290009
# 2015-01-07  301.279999  295.329987  297.500000  298.420013  2640300  298.420013
# 2015-01-08  303.140015  296.109985  300.320007  300.459991  3088400  300.459991

# %%
AM_close_data = AMAZ_15to20['Close']
plt.figure(figsize=(8,8))
plt.plot(AM_close_data, label='Close Price history')
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['Amazon Stock Price, 5 years'])
plt.suptitle('Amazon Stock')
# Out:
# Text(0.5, 0.98, 'Amazon Stock')

# %% [markdown]
# Amazon 10 years data (2010-2020)

# %%
AMAZ_10to20= web.DataReader("AMZN", "yahoo", datetime.datetime(2010,1,1), datetime.date.today())
AMAZ_10to20.head()
# Out:
#                   High         Low  ...    Volume   Adj Close
# Date                                ...
# 2010-01-04  136.610001  133.139999  ...   7599900  133.899994
# 2010-01-05  135.479996  131.809998  ...   8851900  134.690002
# 2010-01-06  134.729996  131.649994  ...   7178800  132.250000
# 2010-01-07  132.320007  128.800003  ...  11030200  130.000000
# 2010-01-08  133.679993  129.029999  ...   9830500  133.520004
#
# [5 rows x 6 columns]

# %%
AM_close_data = AMAZ_10to20['Close']
plt.figure(figsize=(8,8))
plt.plot(AM_close_data, label='Close Price history')
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['Amazon Stock Price, 10 years'])
plt.suptitle('Amazon Stock')
# Out:
# Text(0.5, 0.98, 'Amazon Stock')

# %% [markdown]
# Walmart 5 years data (2015-2020)

# %%
WMT_15to20= web.DataReader("WMT", "yahoo", datetime.datetime(2015,1,1), datetime.date.today())
WMT_15to20.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2015-01-02  86.720001  85.550003  86.269997  85.900002   4501800.0  74.167084
# 2015-01-05  86.320000  85.510002  85.720001  85.650002   6979000.0  73.951225
# 2015-01-06  86.750000  85.790001  85.980003  86.309998   8205100.0  74.521065
# 2015-01-07  88.680000  86.669998  86.779999  88.599998   8498400.0  76.498276
# 2015-01-08  90.669998  89.070000  89.209999  90.470001  12713600.0  78.112862

# %%
WMT_closedata = WMT_15to20['Close']
plt.figure(figsize=(8,8))
plt.plot(WMT_closedata, label='Close Price history')
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['WMT Stock Price, 5 years'])
plt.suptitle('Walmart Stock')
# Out:
# Text(0.5, 0.98, 'Walmart Stock')

# %% [markdown]
# Walmart 10 years data (2010-2020)

# %%
WMT_10to20= web.DataReader("WMT", "yahoo", datetime.datetime(2010,1,1), datetime.date.today())
WMT_10to20.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2010-01-04  54.669998  53.669998  53.740002  54.230000  20753100.0  41.398109
# 2010-01-05  54.189999  53.570000  54.090000  53.689999  15648400.0  40.985886
# 2010-01-06  53.830002  53.419998  53.500000  53.570000  12517200.0  40.894283
# 2010-01-07  53.750000  53.259998  53.720001  53.599998  10662700.0  40.917183
# 2010-01-08  53.529999  53.020000  53.430000  53.330002  11363200.0  40.711075

# %%
WMT_closedata = WMT_10to20['Close']
plt.figure(figsize=(8,8))
plt.plot(WMT_closedata, label='Close Price history')
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['WMT Stock Price, 10 years'])
plt.suptitle('Walmart Stock')
# Out:
# Text(0.5, 0.98, 'Walmart Stock')

# %% [markdown]
# VIX (Volatility) Index 5 years data

# %%
VIX= web.DataReader("^VIX", "yahoo", datetime.datetime(2015,1,1), datetime.date.today())
VIX.head()
# Out:
#                  High        Low       Open      Close  Volume  Adj Close
# Date
# 2015-01-02  20.139999  17.049999  17.760000  17.790001       0  17.790001
# 2015-01-05  21.290001  19.190001  19.190001  19.920000       0  19.920000
# 2015-01-06  22.900000  19.520000  20.330000  21.120001       0  21.120001
# 2015-01-07  20.719999  19.040001  20.150000  19.309999       0  19.309999
# 2015-01-08  18.090000  16.990000  17.930000  17.010000       0  17.010000

# %%
VIX_close_data = VIX['Close']
plt.figure(figsize=(8,8))
plt.plot(VIX_close_data, label='Vix history')
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['VIX'])
plt.suptitle('VIX Index')
# Out:
# Text(0.5, 0.98, 'VIX Index')

# %% [markdown]
# VIX Volatility Index for 10 years data

# %%
VIX10= web.DataReader("^VIX", "yahoo", datetime.datetime(2010,1,1), datetime.date.today())
VIX.head()
# Out:
#                  High        Low       Open      Close  Volume  Adj Close
# Date
# 2015-01-02  20.139999  17.049999  17.760000  17.790001       0  17.790001
# 2015-01-05  21.290001  19.190001  19.190001  19.920000       0  19.920000
# 2015-01-06  22.900000  19.520000  20.330000  21.120001       0  21.120001
# 2015-01-07  20.719999  19.040001  20.150000  19.309999       0  19.309999
# 2015-01-08  18.090000  16.990000  17.930000  17.010000       0  17.010000

# %%
VIX_close_data = VIX10['Close']
plt.figure(figsize=(8,8))
plt.plot(VIX_close_data, label='Vix history')
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['VIX for 10 years'])
plt.suptitle('VIX Index')
# Out:
# Text(0.5, 0.98, 'VIX Index')

# %% [markdown]
# Facebook 5 years data

# %%
yahoo_financials = YahooFinancials('FB')

data = yahoo_financials.get_historical_price_data(start_date='2015-01-01', 
                                                  end_date='2020-10-1', 
                                                  time_interval='daily')

FB_2015 = pd.DataFrame(data['FB']['prices'])
FB_2015 = FB_2015.drop('date', axis=1)
FB_2015['formatted_date'] = pd.to_datetime(FB_2015.formatted_date,format='%Y-%m-%d')
FB_2015.index = FB_2015['formatted_date']
FB_2015 = FB_2015.drop('formatted_date', axis=1)
FB_2015.head()
# Out:
#                      high        low       open      close    volume   adjclose
# formatted_date
# 2015-01-02      78.930000  77.699997  78.580002  78.449997  18177500  78.449997
# 2015-01-05      79.250000  76.860001  77.980003  77.190002  26452200  77.190002
# 2015-01-06      77.589996  75.360001  77.230003  76.150002  27399300  76.150002
# 2015-01-07      77.360001  75.820000  76.760002  76.150002  22045300  76.150002
# 2015-01-08      78.230003  76.080002  76.739998  78.180000  23961000  78.180000

# %%
FB_close_data = FB_2015['close']
plt.figure(figsize=(8,8))
plt.plot(FB_close_data, label='Close Price history')
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['Facebook Stock Price, 5 years'])
plt.suptitle('Facebook Stock')
# Out:
# Text(0.5, 0.98, 'Facebook Stock')

# %%
FB10= web.DataReader("FB", "yahoo", datetime.datetime(2010,1,1), datetime.date.today())
FB10.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2012-05-18  45.000000  38.000000  42.049999  38.230000  573576400  38.230000
# 2012-05-21  36.660000  33.000000  36.529999  34.029999  168192700  34.029999
# 2012-05-22  33.590000  30.940001  32.610001  31.000000  101786600  31.000000
# 2012-05-23  32.500000  31.360001  31.370001  32.000000   73600000  32.000000
# 2012-05-24  33.209999  31.770000  32.950001  33.029999   50237200  33.029999

# %%
FB10_close_data = FB10['Close']
plt.figure(figsize=(8,8))
plt.plot(FB10_close_data, label='Facebook history')
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['Facebook for 8 years'])
plt.suptitle('Facebook Stock')
# Out:
# Text(0.5, 0.98, 'Facebook Stock')

# %%
BABA5= web.DataReader("BABA", "yahoo", datetime.datetime(2015,1,1), datetime.date.today())
BABA5.head()
# Out:
#                   High         Low  ...    Volume   Adj Close
# Date                                ...
# 2015-01-02  104.720001  102.519997  ...  12303400  103.599998
# 2015-01-05  103.019997   99.900002  ...  18337000  101.000000
# 2015-01-06  103.849998  100.110001  ...  15720400  103.320000
# 2015-01-07  104.739998  102.029999  ...  11052200  102.129997
# 2015-01-08  105.339996  102.680000  ...  12942100  105.029999
#
# [5 rows x 6 columns]

# %%
BABA5_close_data = BABA5['Close']
plt.figure(figsize=(8,8))
plt.plot(BABA5_close_data, label='Alibaba history')
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['Alibaba for 5 years'])
plt.suptitle('Alibaba Index')
# Out:
# Text(0.5, 0.98, 'Alibaba Index')

# %%
BABA10= web.DataReader("BABA", "yahoo", datetime.datetime(2010,1,1), datetime.date.today())
BABA10.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2014-09-19  99.699997  89.949997  92.699997  93.889999  271879400  93.889999
# 2014-09-22  92.949997  89.500000  92.699997  89.889999   66657800  89.889999
# 2014-09-23  90.480003  86.620003  88.940002  87.169998   39009800  87.169998
# 2014-09-24  90.570000  87.220001  88.470001  90.570000   32088000  90.570000
# 2014-09-25  91.500000  88.500000  91.089996  88.919998   28598000  88.919998

# %%
BABA10_close_data = BABA10['Close']
plt.figure(figsize=(8,8))
plt.plot(BABA10_close_data, label='Alibaba history')
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['Alibaba for 10 years'])
plt.suptitle('Alibaba Index')
# Out:
# Text(0.5, 0.98, 'Alibaba Index')

# %%
GOOGL5= web.DataReader("GOOGL", "yahoo", datetime.datetime(2015,1,1), datetime.date.today())
GOOGL5.head()
# Out:
#                   High         Low        Open       Close   Volume   Adj Close
# Date
# 2015-01-02  535.799988  527.880005  532.599976  529.549988  1324000  529.549988
# 2015-01-05  527.989990  517.750000  527.150024  519.460022  2059100  519.460022
# 2015-01-06  521.210022  505.549988  520.500000  506.640015  2722800  506.640015
# 2015-01-07  511.489990  503.649994  510.950012  505.149994  2345900  505.149994
# 2015-01-08  507.500000  495.019989  501.510010  506.910004  3652700  506.910004

# %%
GOOGL5_close_data = GOOGL5['Close']
plt.figure(figsize=(8,8))
plt.plot(GOOGL5_close_data, label='GOOGLE history')
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['GOOGLE for 5 years'])
plt.suptitle('GOOGLE Stock')
# Out:
# Text(0.5, 0.98, 'GOOGLE Stock')

# %%
GOOGL10= web.DataReader("GOOGL", "yahoo", datetime.datetime(2010,1,1), datetime.date.today())
GOOGL10.head()
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2010-01-04  315.070068  312.432434  ...   3908400.0  313.688690
# 2010-01-05  314.234222  311.081085  ...   6003300.0  312.307312
# 2010-01-06  313.243256  303.483490  ...   7949400.0  304.434448
# 2010-01-07  305.305298  296.621613  ...  12815700.0  297.347351
# 2010-01-08  301.926941  294.849854  ...   9439100.0  301.311310
#
# [5 rows x 6 columns]

# %%
GOOGL10_close_data = GOOGL10['Close']
plt.figure(figsize=(8,8))
plt.plot(GOOGL10_close_data, label='GOOGLE history')
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['GOOGLE for 10 years'])
plt.suptitle('GOOGLE Stock')
# Out:
# Text(0.5, 0.98, 'GOOGLE Stock')

# %%
EBAY5= web.DataReader("EBAY", "yahoo", datetime.datetime(2015,1,1), datetime.date.today())
EBAY5.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2015-01-02  23.922560  23.455387  23.728956  23.657408  14021200.0  22.975092
# 2015-01-05  23.670034  23.274410  23.505892  23.459597  17694000.0  22.782984
# 2015-01-06  23.484848  23.017677  23.484848  23.156565  22926700.0  22.488691
# 2015-01-07  23.350168  22.912458  23.223906  23.118687  21981500.0  22.451908
# 2015-01-08  23.745790  23.274410  23.278620  23.741583  24326400.0  23.056841

# %%
EBAY5_close_data = EBAY5['Close']
plt.figure(figsize=(8,8))
plt.plot(EBAY5_close_data, label='EBAY history')
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['EBAY for 5 years'])
plt.suptitle('EBAY Stock')
# Out:
# Text(0.5, 0.98, 'EBAY Stock')

# %% [markdown]
# # **Data Summary**

# %%
ticke_5yearr=['AMZN','WMT','EBAY', 'FB','GOOGL','^VIX','BABA']
start_date = '2015-01-01'
panel_data_5years =web.DataReader(ticke_5yearr,'yahoo',start_date, '2020-10-1')
Datatable = panel_data_5years['Close']
Datatable.head()
# Out:
# Symbols           AMZN        WMT       EBAY  ...       GOOGL       ^VIX        BABA
# Date                                          ...
# 2015-01-02  308.519989  85.900002  23.657408  ...  529.549988  17.790001  103.599998
# 2015-01-05  302.190002  85.650002  23.459597  ...  519.460022  19.920000  101.000000
# 2015-01-06  295.290009  86.309998  23.156565  ...  506.640015  21.120001  103.320000
# 2015-01-07  298.420013  88.599998  23.118687  ...  505.149994  19.309999  102.129997
# 2015-01-08  300.459991  90.470001  23.741583  ...  506.910004  17.010000  105.029999
#
# [5 rows x 7 columns]

# %%
print('The length of the datatable is', len(Datatable))
# Out:
# The length of the datatable is 1448

# %% [markdown]
# # **Data Analysis**

# %%
AMZNP = Datatable['AMZN']
WMTP =Datatable['WMT']
EBAYP =Datatable['EBAY']
FBP =Datatable['FB']
GOOGLP =Datatable['GOOGL']
VIXP =Datatable['^VIX']
BABAP =Datatable['BABA']
plt.figure(figsize=(8,8))
plt.plot(AMZNP)
plt.plot(WMTP)
plt.plot(EBAYP)
plt.plot(FBP)
plt.plot(GOOGLP)
plt.plot(VIXP)
plt.plot(BABAP)
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['AMAZON','Walmart','Ebay','Facebook','Googel','VIX INDEX','Alibaba' ])
plt.suptitle('All stocks Daily Close Price for 5 years')
# Out:
# Text(0.5, 0.98, 'All stocks Daily Close Price for 5 years')

# %%
corr = Datatable.corr()
fig, ax = plt.subplots(figsize=(8,8))        
corr_map = sns.heatmap(corr, annot=True, linewidths=.5, ax=ax)

# %%
differ = Datatable
differ = differ.drop('^VIX', axis=1)
differ = differ.pct_change()
differ.head()
# Out:
# Symbols         AMZN       WMT      EBAY        FB     GOOGL      BABA
# Date
# 2015-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-01-05 -0.020517 -0.002910 -0.008361 -0.016061 -0.019054 -0.025097
# 2015-01-06 -0.022833  0.007706 -0.012917 -0.013473 -0.024679  0.022970
# 2015-01-07  0.010600  0.026532 -0.001636  0.000000 -0.002941 -0.011518
# 2015-01-08  0.006836  0.021106  0.026943  0.026658  0.003484  0.028395

# %%
sns.pairplot(differ.dropna())

# %% [markdown]
# # **Trainning Linear Regression Model**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_curve, auc
from sklearn import preprocessing

# %%
AM=Datatable['AMZN']
AM_1=AM[1:1448]
result=AM_1.reset_index()
result = result.drop('Date', axis=1)
x = Datatable
y = result

# %%
x_table = x.reset_index()
x_table = x_table.drop('Date', axis=1)
x_table['Result'] = y

# %%
x_table.head()
# Out:
# Symbols        AMZN        WMT       EBAY  ...       ^VIX        BABA      Result
# 0        308.519989  85.900002  23.657408  ...  17.790001  103.599998  302.190002
# 1        302.190002  85.650002  23.459597  ...  19.920000  101.000000  295.290009
# 2        295.290009  86.309998  23.156565  ...  21.120001  103.320000  298.420013
# 3        298.420013  88.599998  23.118687  ...  19.309999  102.129997  300.459991
# 4        300.459991  90.470001  23.741583  ...  17.010000  105.029999  296.929993
#
# [5 rows x 8 columns]

# %%
x = x_table.drop('Result', axis=1)

# %%
x.head()
# Out:
# Symbols        AMZN        WMT       EBAY  ...       GOOGL       ^VIX        BABA
# 0        308.519989  85.900002  23.657408  ...  529.549988  17.790001  103.599998
# 1        302.190002  85.650002  23.459597  ...  519.460022  19.920000  101.000000
# 2        295.290009  86.309998  23.156565  ...  506.640015  21.120001  103.320000
# 3        298.420013  88.599998  23.118687  ...  505.149994  19.309999  102.129997
# 4        300.459991  90.470001  23.741583  ...  506.910004  17.010000  105.029999
#
# [5 rows x 7 columns]

# %%
y.head()
# Out:
#          AMZN
# 0  302.190002
# 1  295.290009
# 2  298.420013
# 3  300.459991
# 4  296.929993

# %%
x_Train, x_Test, y_Train, y_Test = x.iloc[:1158, :], x.iloc[1158:1446, :], y[:1158], y[1158:1446]

# %%
x_Test
# Out:
# Symbols         AMZN         WMT       EBAY  ...        GOOGL       ^VIX        BABA
# 1158     1807.579956  107.279999  40.310001  ...  1188.900024  17.969999  159.119995
# 1159     1784.920044  105.220001  39.740002  ...  1174.500000  21.090000  159.309998
# 1160     1824.339966  107.410004  40.980000  ...  1196.729980  17.520000  164.029999
# 1161     1762.959961  106.199997  39.639999  ...  1164.250000  22.100000  162.059998
# 1162     1776.119995  112.690002  39.439999  ...  1169.319946  21.180000  166.970001
# ...              ...         ...        ...  ...          ...        ...         ...
# 1441     2999.860107  135.990005  50.680000  ...  1409.390015  28.580000  272.950012
# 1442     3019.790039  136.699997  51.779999  ...  1422.859985  28.510000  269.730011
# 1443     3095.129883  137.270004  52.480000  ...  1439.060059  26.379999  271.089996
# 1444     3174.050049  137.250000  54.040001  ...  1458.660034  26.190001  276.010010
# ...

# %%
logreg = LinearRegression()
logreg.fit(x_Train, y_Train)
y_train_predict = logreg.predict(x_Train)
y_test_predict = logreg.predict(x_Test)

# %%
New_RMSE_TRAIN= (np.sqrt(mean_squared_error(y_Train, y_train_predict)))
New_RMSE_TEST = (np.sqrt(mean_squared_error(y_Test, y_test_predict)))

New_MSE_TRAIN= (mean_squared_error(y_Train, y_train_predict))
New_MSE_TEST = (mean_squared_error(y_Test, y_test_predict))

#New_R2_TRAIN= r2_score(y_Train, y_train_predict)
#New_R2_TEST = r2_score(y_Test, y_test_predict)

# %%
print("Train Model: ")
print('RMSE is :  {}'.format(New_RMSE_TRAIN))
#print('R2 score is :  {}'.format(New_R2_TRAIN))
print('MSE is :  {}'.format(New_MSE_TRAIN))
print("Test Model: ")
print('RMSE is :  {}'.format(New_RMSE_TEST))
#print('R2 score is :  {}'.format(New_R2_TEST))
print('MSE is :  {}'.format(New_MSE_TEST))
# Out:
# Train Model:
# RMSE is :  21.866580977606148
# MSE is :  478.14736365020707
# Test Model:
# RMSE is :  51.48521950278302
# MSE is :  2650.7278272497488

# %%
plt.plot([y_Test.min(),y_Test.max()],[y_Test.min(),y_Test.max()],'k--',lw=2)
plt.scatter(y_Test,y_test_predict)
plt.xlabel('actual price')
plt.ylabel('predicted prices')
plt.show()

# %%
y_true = []
for i in range(len(y_test_predict)):
  y_true.append(y_Test.iloc[i][0])

# %%
plt.figure(figsize = (10,8))
plt.plot(y_test_predict, label = 'Pred')
plt.plot(y_true,label = 'actual')
plt.xlabel('time step')
plt.ylabel('price')
plt.legend()

# %%
Linearmse = mean_squared_error(y_true, y_test_predict)
Linearrmse = np.sqrt(Linearmse)
print(Linearrmse)
# Out:
# 51.48521950278302

# %%
dataset_test = x_table.iloc[1158:1446, :8]

# %%
testmatrix = []
truematrix = []
for i in range(len(dataset_test)-1):
  if dataset_test.iloc[i][0] < dataset_test.iloc[i][7]:
    truematrix.append(1)
  else:
    truematrix.append(0)
  
  if dataset_test.iloc[i][0] < y_test_predict[i]:
    testmatrix.append(1)
  else:
    testmatrix.append(0)
y_actu = pd.Series(truematrix, name='Actual')
y_pred = pd.Series(testmatrix, name='Predicted')
df_confusion = pd.crosstab(y_actu, y_pred)
print('The confusion Matrix is')
print('----------------------------------------')
df_confusion
# Out:
# The confusion Matrix is
# ----------------------------------------
# Predicted  0    1
# Actual
# 0          8  122
# 1          5  152

# %% [markdown]
# # **Quadratic Regression Model**

# %%
from sklearn import neighbors
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
AM=Datatable['AMZN']
AM_1=AM[1:1448]
result=AM_1.reset_index()
result = result.drop('Date', axis=1)
x = Datatable
y = result
x_table = x.reset_index()
x_table = x_table.drop('Date', axis=1)
x_table['Result'] = y
x = x_table.drop('Result', axis=1)

# %%
x_Train, x_Test, y_Train, y_Test = x.iloc[:1158, :], x.iloc[1158:1446, :], y[:1158], y[1158:1446]

# %%
clfpoly2 = make_pipeline(PolynomialFeatures(2), Ridge())
clfpoly2.fit(x_Train, y_Train)
# Out:
# Pipeline(memory=None,
#          steps=[('polynomialfeatures',
#                  PolynomialFeatures(degree=2, include_bias=True,
#                                     interaction_only=False, order='C')),
#                 ('ridge',
#                  Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                        max_iter=None, normalize=False, random_state=None,
#                        solver='auto', tol=0.001))],
#          verbose=False)

# %%
confidencepoly2 = clfpoly2.score(x_Test,y_Test)
print(confidencepoly2)
# Out:
# 0.9829364863552127

# %%
forecast_set = clfpoly2.predict(x_Test)

# %%
Quad2mse = mean_squared_error(y_true, forecast_set)
Quad2rmse = np.sqrt(Quad2mse)
print(np.sqrt(Quad2mse))
# Out:
# 71.7624693883931

# %%
#print(forecast_set)

# %%
plt.figure(figsize = (10,8))
plt.plot(y_true, label = 'actual')
plt.plot(forecast_set,label = 'Pred')
plt.xlabel('time step')
plt.ylabel('price')
plt.legend()

# %%
clfpoly3 = make_pipeline(PolynomialFeatures(3), Ridge())
clfpoly3.fit(x_Train, y_Train)
confidencepoly3 = clfpoly3.score(x_Test,y_Test)
print(confidencepoly3)
# Out:
# -0.845154613442979
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.82372e-23): result may not be accurate.
#   overwrite_a=True).T

# %%
forecast_set2 = clfpoly3.predict(x_Test)

# %%
Quad3mse = mean_squared_error(y_true, forecast_set2)
Quad3rmse = np.sqrt(Quad3mse)
print(np.sqrt(Quad3mse))
# Out:
# 746.2417180854811

# %%
#print(forecast_set2)

# %%
plt.figure(figsize = (10,8))
plt.plot(y_true, label = 'actual')
plt.plot(forecast_set2,label = 'Pred')
plt.xlabel('time step')
plt.ylabel('price')
plt.legend()

# %% [markdown]
# # **Train Deep Neural Network**

# %%
from sklearn import metrics
from sklearn import preprocessing
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
import math
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
def calculate_price(pridect_price,p_AMZN):
  min=p_AMZN.min()
  max=p_AMZN.max()

  y=pridect_price

  x=(y*(max - min))+min
  return x

# %%
Tabel = x_table

# %%
Tabel.head()
# Out:
# Symbols        AMZN        WMT       EBAY  ...       ^VIX        BABA      Result
# 0        308.519989  85.900002  23.657408  ...  17.790001  103.599998  302.190002
# 1        302.190002  85.650002  23.459597  ...  19.920000  101.000000  295.290009
# 2        295.290009  86.309998  23.156565  ...  21.120001  103.320000  298.420013
# 3        298.420013  88.599998  23.118687  ...  19.309999  102.129997  300.459991
# 4        300.459991  90.470001  23.741583  ...  17.010000  105.029999  296.929993
#
# [5 rows x 8 columns]

# %%
X_true = []
for i in range(len(Tabel)):
    X_true.append(Tabel.iloc[i, 0])

# %%
def normalize_data(df):
    min = df.min()
    max = df.max()
    x = df 
    y = (x - min) / (max - min)
    
    return y

# %%
#Amazon norm data
df_AMZN=Datatable['AMZN']
DATA_AMZN=df_AMZN.reset_index()
DATA_AMZN= DATA_AMZN.drop('Date', axis=1)
Tabel['AMZN'] = normalize_data(DATA_AMZN)

#Walmart norm data
df_WMT=Datatable['WMT']
DATA_WMT=df_WMT.reset_index()
DATA_WMT= DATA_WMT.drop('Date', axis=1)
Tabel['WMT'] = normalize_data(DATA_WMT)

#Ebay norm data
df_EBAY=Datatable['EBAY']
DATA_EBAY=df_EBAY.reset_index()
DATA_EBAY= DATA_EBAY.drop('Date', axis=1)
Tabel['EBAY'] = normalize_data(DATA_EBAY)

#Facebook norm data
df_FB=Datatable['FB']
DATA_FB=df_FB.reset_index()
DATA_FB= DATA_FB.drop('Date', axis=1)
Tabel['FB'] = normalize_data(DATA_FB)

#GOOGLE norm data
df_GOOGL=Datatable['GOOGL']
DATA_GOOGL=df_GOOGL.reset_index()
DATA_GOOGL= DATA_GOOGL.drop('Date', axis=1)
Tabel['GOOGL'] = normalize_data(DATA_GOOGL)

#^VIX norm data
df_VIX=Datatable['^VIX']
DATA_VIX=df_VIX.reset_index()
DATA_VIX= DATA_VIX.drop('Date', axis=1)
Tabel['^VIX'] = normalize_data(DATA_VIX)

#Alibaba norm data
df_BABA=Datatable['BABA']
DATA_BABA=df_BABA.reset_index()
DATA_BABA= DATA_BABA.drop('Date', axis=1)
Tabel['BABA'] = normalize_data(DATA_BABA)

#Result norm data
df_R=Tabel['Result']
#DATA_R=df_R.reset_index()
#DATA_R= DATA_R.drop('Date', axis=1)
Tabel['Result'] = normalize_data(df_R)

# %%
Tabel.head()
# Out:
# Symbols      AMZN       WMT      EBAY  ...      ^VIX      BABA    Result
# 0        0.006648  0.323033  0.044214  ...  0.117607  0.192054  0.004697
# 1        0.004697  0.320294  0.038905  ...  0.146567  0.181248  0.002571
# 2        0.002571  0.327526  0.030772  ...  0.162882  0.190890  0.003535
# 3        0.003535  0.352619  0.029755  ...  0.138273  0.185944  0.004164
# 4        0.004164  0.373110  0.046473  ...  0.107002  0.197997  0.003076
#
# [5 rows x 8 columns]

# %%
trainning = Tabel.values

# %%
X_train = []
y_train = []
for i in range(1185):
    X_train.append(trainning[i, 0:7])
    y_train.append(trainning[i, 7])
    #X_train.append(Tabel.iloc[i, 0:7])
    #y_train.append(Tabel[i, 7])
X_train, y_train = np.array(X_train), np.array(y_train)

print('the shape of input trainning data is',X_train[0].shape)
# Out:
# the shape of input trainning data is (7,)

# %%
print(' the size of the trainning data is ', X_train.shape)
# Out:
#  the size of the trainning data is  (1185, 7)

# %%
print(' the size of the trainning label is ', y_train.shape)
# Out:
#  the size of the trainning label is  (1185,)

# %% [markdown]
# ## DNN Model

# %%
DNNmodel = Sequential()

DNNmodel.add(Dense(64, activation='relu' , input_shape=(7,)))
DNNmodel.add(Dense(128, activation='relu'))
DNNmodel.add(Dense(256, activation='relu'))
DNNmodel.add(Dense(512, activation='relu'))
#DNNmodel.add(Dense(512, activation='relu'))
#DNNmodel.add(Dense(256, activation='relu'))
DNNmodel.add(Dense(128, activation='relu'))
DNNmodel.add(Dense(64, activation='relu'))
DNNmodel.add(Dense(1))

DNNmodel.compile(loss='mean_squared_error', optimizer='adam')
DNNmodel.fit(X_train, y_train, epochs = 20, batch_size = 32)
# Out:
# Epoch 1/20
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0080
# Epoch 2/20
# 38/38 [==============================] - 0s 4ms/step - loss: 6.2090e-04
# Epoch 3/20
# 38/38 [==============================] - 0s 4ms/step - loss: 1.3803e-04
# Epoch 4/20
# 38/38 [==============================] - 0s 5ms/step - loss: 1.0565e-04
# Epoch 5/20
# 38/38 [==============================] - 0s 5ms/step - loss: 8.9729e-05
# Epoch 6/20
# 38/38 [==============================] - 0s 4ms/step - loss: 7.9980e-05
# Epoch 7/20
# 38/38 [==============================] - 0s 5ms/step - loss: 2.4569e-04
# Epoch 8/20
# 38/38 [==============================] - 0s 5ms/step - loss: 7.8369e-05
# Epoch 9/20
# 38/38 [==============================] - 0s 5ms/step - loss: 8.0465e-05
# Epoch 10/20
# 38/38 [==============================] - 0s 5ms/step - loss: 7.2633e-05
# Epoch 11/20
# 38/38 [==============================] - 0s 4ms/step - loss: 8.0875e-05
# Epoch 12/20
# ...

# %%
DNNmodel.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_7 (Dense)              (None, 64)                512
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dense_12 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 65
# ...

# %%
from tensorflow.keras.utils import plot_model
plot_model(DNNmodel, to_file='model.png')

# %%
dataset_test = Tabel.iloc[1158:, :8]
X_test = []
for i in range(len(dataset_test)):
    X_test.append(dataset_test.iloc[i, :7].values)
X_test = np.array(X_test)

print('the shape of testing data is',X_test.shape)
predicted_stock_price = DNNmodel.predict(X_test)
print('the predicted price shape',predicted_stock_price.shape)
# Out:
# the shape of testing data is (290, 7)
# the predicted price shape (290, 1)

# %%
testmatrix = []
truematrix = []
for i in range(len(dataset_test)):
  if dataset_test.iloc[i][0] <= dataset_test.iloc[i][7]:
    truematrix.append(1)
  else:
    truematrix.append(0)
  
  if dataset_test.iloc[i][0] <= predicted_stock_price[i]:
    testmatrix.append(1)
  else:
    testmatrix.append(0)

y_actu = pd.Series(truematrix, name='Actual')
y_pred = pd.Series(testmatrix, name='Predicted')
df_confusion = pd.crosstab(y_actu, y_pred)
print('The confusion Matrix is')
print('----------------------------------------')
df_confusion
# Out:
# The confusion Matrix is
# ----------------------------------------
# Predicted    1
# Actual
# 0          131
# 1          159

# %%
Predict_P=()
p_AMZN=Datatable['AMZN']
pridect_price=predicted_stock_price
Predict_P=calculate_price(pridect_price, p_AMZN)
print(len(Predict_P))

actual_p=Datatable['AMZN']
ACP=actual_p.iloc[1158:].values

plt.figure(figsize = (8,5))
plt.plot(Predict_P, label = 'Pred')
plt.plot(ACP,label = 'actual')
plt.xlabel('time step')
plt.ylabel('price')
plt.legend()
# Out:
# 290

# %%
def outpout_data(ACP, Predict_P):
  new_pred=[]
  new_pred.append(ACP[0])
  for i in range(len(ACP)-1):
    diff=[]
    output_price=[]
    diff=Predict_P[i+1] - Predict_P[i]
    output=ACP[i]+diff
    new_pred.append(output)
  return new_pred

# %%
adjusted_data=outpout_data(ACP, Predict_P)

# %%
plt.figure(figsize = (8,5))
plt.plot(ACP,label = 'actual')
plt.plot(adjusted_data,label = 'adjusted')
plt.xlabel('time step')
plt.ylabel('price')
plt.legend()

# %%
DNN_Beforemse = mean_squared_error(ACP, Predict_P)
DNN_Beforermse = np.sqrt(DNN_Beforemse)
print(DNN_Beforermse)
# Out:
# 137.92572847682632

# %%
DNNmse = mean_squared_error(ACP, adjusted_data)
DNNrmse = np.sqrt(DNNmse)
print(DNNrmse)
# Out:
# 15.564820134208736

# %%
testmatrix = []
truematrix = []
for i in range(len(dataset_test)):
  if dataset_test.iloc[i][0] <= dataset_test.iloc[i][7]:
    truematrix.append(1)
  else:
    truematrix.append(0)
  
  if dataset_test.iloc[i][0] <= adjusted_data[i]:
    testmatrix.append(1)
  else:
    testmatrix.append(0)

y_actu = pd.Series(truematrix, name='Actual')
y_pred = pd.Series(testmatrix, name='Predicted')
df_confusion = pd.crosstab(y_actu, y_pred)
print('The confusion Matrix is')
print('----------------------------------------')
df_confusion
# Out:
# The confusion Matrix is
# ----------------------------------------
# Predicted    1
# Actual
# 0          131
# 1          159

# %% [markdown]
# ## LSTM Model

# %%
print(len(trainning[0]))
# Out:
# 8

# %%
X_train = []
y_train = []
for i in range(60, 1185):
    X_train.append(trainning[i-60:i, 0:7])
    y_train.append(trainning[i-1, 7])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 7))

print('the shape of input trainning data is',X_train[0].shape)
# Out:
# the shape of input trainning data is (60, 7)

# %%
model = Sequential()
model.add(LSTM(units = 256, return_sequences = True, input_shape = (60,7)))
#model.add(Dropout(0.2))
model.add(LSTM(units = 512, return_sequences = True))
#model.add(Dropout(0.2))
model.add(LSTM(units = 512, return_sequences = True))
#model.add(Dropout(0.2))
model.add(LSTM(units = 512))
#model.add(Dropout(0.2))
model.add(Dense(units = 1))

model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(X_train, y_train, epochs = 50, batch_size = 32)
# Out:
# Epoch 1/50
# 36/36 [==============================] - 6s 39ms/step - loss: 0.0431
# Epoch 2/50
# 36/36 [==============================] - 1s 37ms/step - loss: 7.9644e-04
# Epoch 3/50
# 36/36 [==============================] - 1s 37ms/step - loss: 4.1172e-04
# Epoch 4/50
# 36/36 [==============================] - 1s 37ms/step - loss: 4.0637e-04
# Epoch 5/50
# 36/36 [==============================] - 1s 38ms/step - loss: 2.5819e-04
# Epoch 6/50
# 36/36 [==============================] - 1s 38ms/step - loss: 4.0577e-04
# Epoch 7/50
# 36/36 [==============================] - 1s 38ms/step - loss: 2.8206e-04
# Epoch 8/50
# 36/36 [==============================] - 1s 38ms/step - loss: 4.1962e-04
# Epoch 9/50
# 36/36 [==============================] - 1s 38ms/step - loss: 3.7736e-04
# Epoch 10/50
# 36/36 [==============================] - 1s 38ms/step - loss: 4.9456e-04
# Epoch 11/50
# 36/36 [==============================] - 1s 38ms/step - loss: 2.1137e-04
# Epoch 12/50
# ...

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_36 (LSTM)               (None, 60, 256)           270336
# _________________________________________________________________
# lstm_37 (LSTM)               (None, 60, 512)           1574912
# _________________________________________________________________
# lstm_38 (LSTM)               (None, 60, 512)           2099200
# _________________________________________________________________
# lstm_39 (LSTM)               (None, 512)               2099200
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 513
# ...
# Total params: 6,044,161
# Trainable params: 6,044,161
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
# Extract testing data
dataset_test = Tabel.iloc[1158:, :8]

# %%
dataset_test.head()
# Out:
# Symbols      AMZN       WMT      EBAY  ...      ^VIX      BABA    Result
# 1158     0.468679  0.557309  0.491143  ...  0.120054  0.422800  0.461695
# 1159     0.461695  0.534736  0.475845  ...  0.162474  0.423590  0.473845
# 1160     0.473845  0.558733  0.509125  ...  0.113936  0.443207  0.454927
# 1161     0.454927  0.545474  0.473162  ...  0.176207  0.435019  0.458983
# 1162     0.458983  0.616590  0.467794  ...  0.163698  0.455426  0.464053
#
# [5 rows x 8 columns]

# %%
X_test = []
for i in range(60, len(dataset_test)):
    X_test.append(dataset_test.iloc[i-60:i, :7].values)
X_test = np.array(X_test)

# %%
print('the shape of testing data is',X_test.shape)
# Out:
# the shape of testing data is (230, 60, 7)

# %%
predicted_stock_price = model.predict(X_test)
print('the predicted price shape',predicted_stock_price.shape)
# Out:
# the predicted price shape (230, 1)

# %%
testmatrix = []
truematrix = []
for i in range(len(predicted_stock_price)):
  if dataset_test.iloc[i][0] <= dataset_test.iloc[i][7]:
    truematrix.append(1)
  else:
    truematrix.append(0)
  
  if dataset_test.iloc[i][0] <= predicted_stock_price[i]:
    testmatrix.append(1)
  else:
    testmatrix.append(0)

y_actu = pd.Series(truematrix, name='Actual')
y_pred = pd.Series(testmatrix, name='Predicted')
df_confusion = pd.crosstab(y_actu, y_pred)
print('The confusion Matrix is')
print('----------------------------------------')
df_confusion
# Out:
# The confusion Matrix is
# ----------------------------------------
# Predicted   0    1
# Actual
# 0          17   84
# 1          10  119

# %%
#print(predicted_stock_price)

# %%
def calculate_price(pridect_price,p_AMZN):
  min=p_AMZN.min()
  max=p_AMZN.max()

  y=pridect_price

  x=(y*(max - min))+min
  return x

# %%
#Amazon norm data
Predict_P=()
p_AMZN=Datatable['AMZN']
pridect_price=predicted_stock_price
Predict_P=calculate_price(pridect_price, p_AMZN)
print(len(Predict_P))
# Out:
# 230

# %%
actual_p=Datatable['AMZN']
ACP=actual_p.iloc[1218:].values
print(len(ACP))
# Out:
# 230

# %%
#Predict_P=np.array(Predict_P)
#ACP= ACP.drop('Date', axis=1)
ACP_p=np.array(ACP)
c=[[Predict_P]]
final_Predict= pd.DataFrame(c,columns=['Predict Price'])

# %%
def outpout_data(ACP, Predict_P):
  new_pred=[]
  new_pred.append(ACP[0])
  for i in range(len(ACP)-1):
    diff=[]
    output_price=[]
    diff=Predict_P[i+1] - Predict_P[i]
    output=ACP[i]+diff
    new_pred.append(output)
  return new_pred

# %%
adjusted_data=outpout_data(ACP, Predict_P)

# %%
plt.figure(figsize = (8,5))
plt.plot(Predict_P, label = 'Pred')
plt.plot(ACP,label = 'actual')
#plt.plot(adjusted_data,label = 'adjusted')
plt.xlabel('time step')
plt.ylabel('price')
plt.legend()

# %%
plt.figure(figsize = (8,5))
#plt.plot(Predict_P, label = 'Pred')
plt.plot(ACP,label = 'actual')
plt.plot(adjusted_data,label = 'adjusted')
plt.xlabel('time step')
plt.ylabel('price')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
Before_LSTMmse = mean_squared_error(ACP, Predict_P)
Before_LSTMrmse = np.sqrt(Before_LSTMmse)
print(Before_LSTMrmse)
# Out:
# 96.1510992151124

# %%
LSTMmse = mean_squared_error(ACP, adjusted_data)
LSTMrmse = np.sqrt(LSTMmse)
print(LSTMrmse)
# Out:
# 64.32183760052096
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # **Results**

# %%
resultstable={'Linear Regression':[Linearrmse], 
              'Quadratic Regression_2':[Quad2rmse],
              'Quadratic Regression_3':[Quad3rmse],
              'Deep Neural Network':[DNNrmse],
              'Long Short-Term Memory':[LSTMrmse]}

# %%
RT=pd.DataFrame(data=resultstable)
RT.head()
# Out:
#    Linear Regression  ...  Long Short-Term Memory
# 0           51.48522  ...               58.096471
#
# [1 rows x 5 columns]
